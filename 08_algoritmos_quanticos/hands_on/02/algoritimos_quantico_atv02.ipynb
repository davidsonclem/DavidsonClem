# %% [markdown]
# <a href="https://colab.research.google.com/github/davidsonclem/DavidsonClem/blob/master/08_algoritmos_quanticos/hands_on/02/algoritimos_quantico_atv02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# UNIVERSIDADE SENAI CIMATEC
# CURSO DE ESPECIALIZAÇÃO EM COMPUTAÇÃO QUÂNTICA

## Hands-On 01: Algoritmo de Grover

### **Disciplina:** Algoritimos Quânticos

### **Turma:** 98895

### **Objetivos da Atividade**

* Implementar o código do algoritmo de Grover em Python;.
* Explicar o papel do oráculo no **algoritmo de Grover**.
* Explicar limitações e aspectos de escalabilidade do algoritmo.

### **Conteúdo Formativo**

* Algoritmo de Grover

---

### **Dados da Atividade**

* **Professor:** Dr.gustavo Arruda
* **Alunos/Equipe:**
    * Davidson Corrêa Clem
    * João Filipe Muchanga
    * José Hidalgo Suárez

* **Data:**  15/03/2026

---
